# %% [markdown]
# ## Setup

# %%
# imports
import pandas as pd
import glob
import os

# geocoding imports
import geopandas as gpd
from shapely.geometry import Point

# %%
# find the csv files
files_list = glob.glob(os.path.join('Resources', '*.csv'))

# combine them
dfs = []

for file in files_list:
    df = pd.read_csv(file)
    dfs.append(df)

citibike_df = pd.concat(dfs, ignore_index=True)

# display df
citibike_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0744109F13385D1D  electric_bike  2024-01-15 15:18:07  2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike  2024-01-13 15:32:50  2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike  2024-01-19 13:11:00  2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike  2024-01-23 07:03:49  2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike  2024-01-01 16:46:10  2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# 0  40.712297 -74.038185  40.737604 -74.052478        member
# 1  40.715391 -74.049692  40.719410 -74.043090        member
# 2  40.712419 -74.038526  40.716366 -74.034344        member
# 3  40.712419 -74.038526  40.716366 -74.034344        member
# 4  40.712419 -74.038526  40.719252 -74.034234        member

# %%
# get the stations df
station_path = 'Output/stations.csv'
stations_df = pd.read_csv(station_path)

# display
stations_df.head()
# Out:
#   short_name                      name  region_id        lat        lon
# 0    7082.08            23 Ave & 31 St       71.0  40.774233 -73.912749
# 1    3460.06             2 Ave & 37 St       71.0  40.656240 -74.009330
# 2    8472.06  Valentine Ave & E 183 St       71.0  40.856987 -73.898237
# 3    5540.06             56 Dr & 61 St       71.0  40.723680 -73.904580
# 4    8717.07     E 201 St & Briggs Ave       71.0  40.872070 -73.884590

# %% [markdown]
# ## Data Check
# ---

# %% [markdown]
# #### Update data types

# %%
# check data types
citibike_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# check for amount of nulls 
citibike_df.isnull().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3061
# end_station_id        3338
# start_lat                0
# start_lng                0
# end_lat                353
# end_lng                353
# member_casual            0
# dtype: int64

# %%
# update dates to datetime
date_format='mixed'
citibike_df['started_at'] = pd.to_datetime(citibike_df['started_at'], format=date_format)
citibike_df['ended_at'] = pd.to_datetime(citibike_df['ended_at'], format=date_format)

# %%
# check for datetime
citibike_df.select_dtypes('datetime64[ns]')
# Out:
#                      started_at                ended_at
# 0       2024-01-15 15:18:07.000 2024-01-15 15:32:44.000
# 1       2024-01-13 15:32:50.000 2024-01-13 15:36:18.000
# 2       2024-01-19 13:11:00.000 2024-01-19 13:14:44.000
# 3       2024-01-23 07:03:49.000 2024-01-23 07:07:11.000
# 4       2024-01-01 16:46:10.000 2024-01-01 16:50:31.000
# ...                         ...                     ...
# 1052446 2024-12-28 09:45:30.704 2024-12-28 09:48:02.706
# 1052447 2024-12-12 16:21:50.427 2024-12-12 16:26:34.069
# 1052448 2024-12-11 19:23:24.109 2024-12-11 19:25:07.612
# 1052449 2024-12-12 20:48:40.471 2024-12-12 20:52:41.722
# 1052450 2024-12-04 18:14:12.686 2024-12-04 18:19:02.621
#
# [1052451 rows x 2 columns]

# %% [markdown]
# #### Check unique values

# %%
citibike_df.shape
# Out:
# (1052451, 13)

# %%
# check number of unique values per column
citibike_df.nunique()
# Out:
# ride_id               1052427
# rideable_type               2
# started_at            1043629
# ended_at              1044175
# start_station_name        205
# start_station_id          205
# end_station_name          519
# 382024 2024-06-01 00:08:15.597                            Willow Ave & 12 St
# 420824 2024-06-01 00:19:15.541                            Willow Ave & 12 St
# 342478 2024-06-01 00:19:15.000                            Willow Ave & 12 St
# 344898 2024-06-01 00:04:32.000                                Riverview Park
# 365469 2024-06-01 00:04:32.393                                Riverview Park
# 283208 2024-06-01 00:02:46.000                                       Hilltop
# 360448 2024-06-01 00:02:46.613                                       Hilltop
# 261235 2024-06-01 12:37:11.000  South Waterfront Walkway - Sinatra Dr & 1 St
# 414958 2024-06-01 12:37:11.351  South Waterfront Walkway - Sinatra Dr & 1 St
# 323589 2024-06-01 03:25:18.000                                Jackson Square
# 370877 2024-06-01 03:25:18.731                                Jackson Square
# 397037 2024-06-01 00:01:28.283  South Waterfront Walkway - Sinatra Dr & 1 St
# 330944 2024-06-01 00:01:28.000  South Waterfront Walkway - Sinatra Dr & 1 St
# 421370 2024-06-01 00:19:19.930                            Willow Ave & 12 St
# 342532 2024-06-01 00:19:19.000                            Willow Ave & 12 St
# 283513 2024-06-01 00:04:19.000       Hoboken Terminal - River St & Hudson Pl
# 451384 2024-06-01 00:04:19.105       Hoboken Terminal - River St & Hudson Pl
# 265518 2024-06-01 00:04:56.000  South Waterfront Walkway - Sinatra Dr & 1 St
# 431673 2024-06-01 00:04:56.895  South Waterfront Walkway - Sinatra Dr & 1 St
# 341760 2024-06-01 00:07:42.000                            Willow Ave & 12 St
# 382049 2024-06-01 00:07:42.382                            Willow Ave & 12 St
#
#        start_station_id                   end_station_name end_station_id  \
# 420821            HB505                 Willow Ave & 12 St          HB505
# 342531            HB505                 Willow Ave & 12 St          HB505
# 360447            JC019               York St & Marin Blvd          JC097
# 283209            JC019               York St & Marin Blvd          JC097
# 256909            HB103         Hoboken Ave at Monmouth St          JC105
# 414293            HB103         Hoboken Ave at Monmouth St          JC105
# 363069            HB102                  Madison St & 1 St          HB402
# 273924            HB102                  Madison St & 1 St          HB402
# 395980            HB610   City Hall - Washington St & 1 St          HB105
# 305232            HB610   City Hall - Washington St & 1 St          HB105
# 294418            HB101                     Pershing Field          JC024
# 456279            HB101                     Pershing Field          JC024
# 385653            HB505   City Hall - Washington St & 1 St          HB105
# 341745            HB505   City Hall - Washington St & 1 St          HB105
# 421707            HB501                                NaN            NaN
# 262047            HB501                                NaN            NaN
# 264645            JC095                 Grant Ave & MLK Dr          JC107
# 416802            JC095                 Grant Ave & MLK Dr          JC107
# 370876            JC063                                NaN            NaN
# 323588            JC063                                NaN            NaN
# 370875            JC063                                NaN            NaN
# 323621            JC063                                NaN            NaN
# 273089            HB608                     Columbus Drive          JC014
# 350911            HB608                     Columbus Drive          JC014
# 431358            HB103               12 St & Sinatra Dr N          HB201
# 265517            HB103               12 St & Sinatra Dr N          HB201
# 341761            HB505   City Hall - Washington St & 1 St          HB105
# 382024            HB505   City Hall - Washington St & 1 St          HB105
# 420824            HB505                 Willow Ave & 12 St          HB505
# 342478            HB505                 Willow Ave & 12 St          HB505
# 344898            JC057                            Hilltop          JC019
# 365469            JC057                            Hilltop          JC019
# 370877  40.711156 -74.078877  40.710000 -74.090000        casual
# 397037  40.736982 -74.027781  40.740814 -74.027406        casual
# 330944  40.736982 -74.027781  40.740814 -74.027406        casual
# 421370  40.751867 -74.030377  40.751867 -74.030377        casual
# 342532  40.751867 -74.030377  40.751867 -74.030377        casual
# 283513  40.736068 -74.029127  40.752961 -74.024353        casual
# 451384  40.736068 -74.029127  40.752961 -74.024353        casual
# 265518  40.736982 -74.027781  40.750604 -74.024020        casual
# 431673  40.736982 -74.027781  40.750604 -74.024020        casual
# 341760  40.751920 -74.030333  40.737360 -74.030970        casual
# 382049  40.751920 -74.030333  40.737360 -74.030970        casual

# %%
# drop duplicate rows
citibike_df = citibike_df.drop_duplicates(subset=['ride_id'], keep='first')

# show number of unique ride id rows versus count
print(f'Total: {citibike_df['ride_id'].count()}')
print(f'Unique: {citibike_df['ride_id'].nunique()}')
# Out:
# Total: 1052427
# Unique: 1052427

# %% [markdown]
# ## Reverse Geocoding
# ---

# %% [markdown]
# ### Get GeoDataFrames

# %% [markdown]
# #### CitiBike gdf

# %%
# create geometry columsn of point objects from lat/lng
citibike_df['geometry_start'] = gpd.points_from_xy(citibike_df['start_lng'], citibike_df['start_lat'])
citibike_df['geometry_end'] = gpd.points_from_xy(citibike_df['end_lng'], citibike_df['end_lat'])


# construct gdf
citibike_gdf = gpd.GeoDataFrame(
    citibike_df,
    geometry='geometry_start',  #current active geometry
    crs='EPSG:4326'
)

# %%
# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual  \
# 0  40.712297 -74.038185  40.737604 -74.052478        member
# 1  40.715391 -74.049692  40.719410 -74.043090        member
# 2  40.712419 -74.038526  40.716366 -74.034344        member
# 3  40.712419 -74.038526  40.716366 -74.034344        member
# 4  40.712419 -74.038526  40.719252 -74.034234        member
#
#            geometry_start            geometry_end
# 0  POINT (-74.038 40.712)  POINT (-74.052 40.738)
# 1   POINT (-74.05 40.715)  POINT (-74.043 40.719)
# 2  POINT (-74.039 40.712)  POINT (-74.034 40.716)
# 3  POINT (-74.039 40.712)  POINT (-74.034 40.716)
# 4  POINT (-74.039 40.712)  POINT (-74.034 40.719)

# %% [markdown]
# #### Cities, Counties, States gdf

# %%
# find county subdivisions shapefiles
cousub_shp_list = glob.glob(os.path.join('Resources/Shapefiles_Cousub/Cousub_*/*.shp'))

# read in each county subdivision file into list
list_cousub_gdf = []

for folder in cousub_shp_list:
    cousub_gdf = gpd.read_file(folder).to_crs('EPSG:4326')
    list_cousub_gdf.append(cousub_gdf)

# combine gdfs into one gdf
cousubs_gdf = pd.concat(list_cousub_gdf, ignore_index=True)

# display
cousub_gdf.head()
# Out:
#   STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID              GEOIDFQ  \
# 0      42      121    27832  01217144  4212127832  0600000US4212127832
# 1      42      079    67456  01216732  4207967456  0600000US4207967456
# 2      42      079    78384  01216735  4207978384  0600000US4207978384
# 3      42      079    83136  01215412  4207983136  0600000US4207983136
# 4      42      057    05144  01216475  4205705144  0600000US4205705144
#
#             NAME               NAMELSAD LSAD CLASSFP  MTFCC FUNCSTAT  \
# 0    Frenchcreek   Frenchcreek township   44      T1  G4040        A
# 1          Salem         Salem township   44      T1  G4040        A
# 2          Union         Union township   44      T1  G4040        A
# 3  West Hazleton  West Hazleton borough   21      C5  G4040        F
# 4        Belfast       Belfast township   44      T1  G4040        A
#
#        ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0   75458260   538510  +41.3968254  -079.9437494
# 1   74442584  2681721  +41.1059794  -076.1835786
# 2   51285654  1126850  +41.2000871  -076.1515620
# 3    4088525        0  +40.9743238  -076.0254145
# 4  129879111        0  +39.8810245  -078.1405196
#
#                                             geometry
# 0  POLYGON ((-80 41.387, -80 41.387, -80 41.387, ...
# 1  POLYGON ((-76.229 41.138, -76.221 41.142, -76....
# 2  POLYGON ((-76.21 41.214, -76.202 41.22, -76.20...
# 3  POLYGON ((-76.038 40.978, -76.036 40.978, -76....
# 4  POLYGON ((-78.216 39.855, -78.216 39.856, -78....

# %%
# read in county shapefile
counties_shapefile = 'Resources/Shapefile_Counties'
counties_gdf = gpd.read_file(counties_shapefile).to_crs('EPSG:4326')

# look at geodataframe
counties_gdf.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID         GEOIDFQ       NAME  \
# 0      31      039  00835841  31039  0500000US31039     Cuming
# 1      53      069  01513275  53069  0500000US53069  Wahkiakum
# 2      35      011  00933054  35011  0500000US35011    De Baca
# 3      31      109  00835876  31109  0500000US31109  Lancaster
# 4      31      129  00835886  31129  0500000US31129   Nuckolls
#
#            NAMELSAD LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT  \
# 0     Cuming County   06      H1  G4020  None   None     None        A
# 1  Wahkiakum County   06      H1  G4020  None   None     None        A
# 2    De Baca County   06      H1  G4020  None   None     None        A
# 3  Lancaster County   06      H1  G4020   339  30700     None        A
# 4   Nuckolls County   06      H1  G4020  None   None     None        A
#
#         ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0  1477563042  10772508  +41.9158651  -096.7885168
# 1   680980773  61564428  +46.2946377  -123.4244583
# 2  6016818941  29090018  +34.3592729  -104.3686961
# 3  2169269508  22850511  +40.7835474  -096.6886584
# 4  1489645201   1718484  +40.1764918  -098.0468422
#
#                                             geometry
# 0  POLYGON ((-96.555 41.829, -96.555 41.828, -96....
# 1  POLYGON ((-123.73 46.264, -123.73 46.265, -123...
# 2  POLYGON ((-104.89 34.089, -104.89 34.089, -104...
# 3  POLYGON ((-96.685 40.523, -96.692 40.523, -96....
# 4  POLYGON ((-98.274 40.118, -98.274 40.122, -98....

# %% [markdown]
# #### zipcodes gdf

# %%
# read zip code shapefile
zip_shapefile = 'Resources/Shapefile_ZipCode'
zip_gdf = gpd.read_file(zip_shapefile).to_crs('EPSG:4326')

# look at geodataframe
zip_gdf.head()
# Out:
#   ZCTA5CE20 GEOID20       GEOIDFQ20 CLASSFP20 MTFCC20 FUNCSTAT20  ALAND20  \
# 0     47236   47236  860Z200US47236        B5   G6350          S  1029063
# 1     47870   47870  860Z200US47870        B5   G6350          S     8830
# 2     47851   47851  860Z200US47851        B5   G6350          S    53326
# 3     47337   47337  860Z200US47337        B5   G6350          S   303089
# 4     47435   47435  860Z200US47435        B5   G6350          S    13302
#
#    AWATER20   INTPTLAT20    INTPTLON20  \
# 0         0  +39.1517426  -085.7252769
# 1         0  +39.3701518  -087.4735141
# 2         0  +39.5735839  -087.2459559
# 3         0  +39.8027537  -085.4372850
# 4         0  +39.2657557  -086.2951577
#
#                                             geometry
# 0  POLYGON ((-85.734 39.156, -85.728 39.156, -85....
# 1  POLYGON ((-87.474 39.37, -87.474 39.37, -87.47...
# 2  POLYGON ((-87.248 39.574, -87.247 39.574, -87....
# 3  POLYGON ((-85.444 39.803, -85.443 39.803, -85....
# 4  POLYGON ((-86.296 39.265, -86.296 39.266, -86....

# %% [markdown]
# ### Get Zipcodes

# %%
# join with zipcode gdf (start)
start_zips_joined_gdf = gpd.sjoin(citibike_gdf, zip_gdf, how='left', predicate='within')

# rename zip column
start_zips_joined_gdf = start_zips_joined_gdf.rename(columns={'ZCTA5CE20': 'start_zip'})

# merge start_zip back into citibike gdf
citibike_gdf['start_zip'] = start_zips_joined_gdf['start_zip']

# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual  \
# 0  40.712297 -74.038185  40.737604 -74.052478        member
# 1  40.715391 -74.049692  40.719410 -74.043090        member
# 2  40.712419 -74.038526  40.716366 -74.034344        member
# 3  40.712419 -74.038526  40.716366 -74.034344        member
# 4  40.712419 -74.038526  40.719252 -74.034234        member
#
#            geometry_start            geometry_end start_zip
# 0  POINT (-74.038 40.712)  POINT (-74.052 40.738)     07302
# 1   POINT (-74.05 40.715)  POINT (-74.043 40.719)     07302
# 2  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302
# 3  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302
# 4  POINT (-74.039 40.712)  POINT (-74.034 40.719)     07302

# %%
# set end geometry to active geometry
ends_gdf = gpd.GeoDataFrame(
    citibike_df.copy(),
    geometry='geometry_end',
    crs='EPSG:4326'
)

# create end zip column
ends_joined_gdf = gpd.sjoin(ends_gdf, zip_gdf, how='left', predicate='within').rename(columns={'ZCTA5CE20': 'end_zip'})

# assign end zip to main gdf
citibike_gdf['end_zip'] = ends_joined_gdf['end_zip']

# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual  \
# 0  40.712297 -74.038185  40.737604 -74.052478        member
# 1  40.715391 -74.049692  40.719410 -74.043090        member
# 2  40.712419 -74.038526  40.716366 -74.034344        member
# 3  40.712419 -74.038526  40.716366 -74.034344        member
# 4  40.712419 -74.038526  40.719252 -74.034234        member
#
#            geometry_start            geometry_end start_zip end_zip
# 0  POINT (-74.038 40.712)  POINT (-74.052 40.738)     07302   07306
# 1   POINT (-74.05 40.715)  POINT (-74.043 40.719)     07302   07302
# 2  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302   07302
# 3  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302   07302
# 4  POINT (-74.039 40.712)  POINT (-74.034 40.719)     07302   07311

# %% [markdown]
# #### Double checking zips--> missing end zips (right outside of boundaries such as on water)

# %%
# look into null values
citibike_gdf.isnull().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3057
# end_station_id        3334
# start_lat                0
# start_lng                0
# end_lat                352
# end_lng                352
# member_casual            0
# geometry_start           0
# geometry_end             0
# start_zip                0
# end_zip                402
# dtype: int64

# %%
# see why there are more null end zips than end coordinates
end_zip_nulls_gdf = citibike_gdf[citibike_gdf['end_zip'].isna() & citibike_gdf['end_lat'].notna()].copy()
end_zip_nulls_gdf.isnull().sum()
# Out:
# ride_id                0
# rideable_type          0
POINT (-74.039 40.718)  POINT (-74.011 40.728)     07302     NaN
# 664530  POINT (-74.043 40.715)  POINT (-74.011 40.728)     07302     NaN
# 679575  POINT (-74.035 40.724)  POINT (-74.011 40.728)     07310     NaN
# 686615  POINT (-74.035 40.724)  POINT (-74.011 40.728)     07310     NaN
# 713882  POINT (-74.044 40.744)     POINT (-74.01 40.7)     07307     NaN

# %% [markdown]
# #### Add missing end zips using nearest approach

# %%
# fix gdf setup of end zip nulls with end coordinates
end_zip_nulls_gdf = end_zip_nulls_gdf.iloc[:, :-1].reset_index(drop=True)

# set geometry to end coordinates and crs
end_zip_nulls_gdf = gpd.GeoDataFrame(
    end_zip_nulls_gdf,
    geometry='geometry_end',
    crs='EPSG:4326'
)

# display
end_zip_nulls_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  305A1F7966180481  electric_bike 2024-01-18 19:11:25 2024-01-18 20:31:32
# 1  95A3E7FABA1D387A  electric_bike 2024-02-11 17:27:28 2024-02-11 18:31:07
# 2  856D6561FC3B2A56   classic_bike 2024-03-15 08:41:23 2024-03-15 09:06:52
# 3  4A50280C500E4ACD  electric_bike 2024-04-19 08:54:45 2024-04-19 09:12:12
# 4  1EFFA98AFA13BD36   classic_bike 2024-05-07 08:44:02 2024-05-07 09:05:51
#
#   start_station_name start_station_id             end_station_name  \
# 0         Harborside            JC104                          NaN
# 1          Warren St            JC006                          NaN
# 2     Columbus Drive            JC014  Pier 40 - Hudson River Park
# 3     Columbus Drive            JC014  Pier 40 - Hudson River Park
# 4     Columbus Drive            JC014  Pier 40 - Hudson River Park
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0            NaN  40.719260 -74.034342  40.720000 -74.020000        member
# 1            NaN  40.721105 -74.038006  40.720000 -74.040000        casual
# 2        5696.03  40.718355 -74.038914  40.727714 -74.011296        member
# 3        5696.03  40.718774 -74.038901  40.727714 -74.011296        member
# 4        5696.03  40.718355 -74.038914  40.727714 -74.011296        member
#
#            geometry_start            geometry_end start_zip
# 0  POINT (-74.034 40.719)    POINT (-74.02 40.72)     07311
# 1  POINT (-74.038 40.721)    POINT (-74.04 40.72)     07302
# 2  POINT (-74.039 40.718)  POINT (-74.011 40.728)     07302
# 3  POINT (-74.039 40.719)  POINT (-74.011 40.728)     07302
# 4  POINT (-74.039 40.718)  POINT (-74.011 40.728)     07302

# %%
# reproject points and zip polygons to local projected crs
ends_proj = end_zip_nulls_gdf.to_crs('EPSG:2263')
zip_proj = zip_gdf.to_crs('EPSG:2263')

# %%
# nearest spatial join to get zips
end_zip_nearest_gdf = gpd.sjoin_nearest(
    ends_proj, zip_proj,
    how='left',
    distance_col='dist_to_zip'
)

# rename zip column
end_zip_nearest_gdf = end_zip_nearest_gdf.rename(columns={'ZCTA5CE20': 'nearest_end_zip'})

# %%
# looking into zips
end_zip_nearest_gdf[['ride_id', 'end_lat', 'end_lng', 'geometry_end', 'nearest_end_zip', 'dist_to_zip']]
# Out:
#              ride_id    end_lat    end_lng               geometry_end  \
# 0   305A1F7966180481  40.720000 -74.020000  POINT (9.79e+05 2.02e+05)
# 1   95A3E7FABA1D387A  40.720000 -74.040000  POINT (9.73e+05 2.02e+05)
# 2   856D6561FC3B2A56  40.727714 -74.011296  POINT (9.81e+05 2.04e+05)
# 3   4A50280C500E4ACD  40.727714 -74.011296  POINT (9.81e+05 2.04e+05)
# 4   1EFFA98AFA13BD36  40.727714 -74.011296  POINT (9.81e+05 2.04e+05)
#
# 26           07302     0.000000
# 27           07302     0.000000
# 28           11106     0.000000
# 29           10014   103.879678
# 30           07307     0.000000
# 31           07307     0.000000
# 32           07307     0.000000
# 33           07307     0.000000
# 34           07307     0.000000
# 35           07307     0.000000
# 36           07307     0.000000
# 37           07307     0.000000
# 38           07307     0.000000
# 39           10014   103.879678
# 40           07302     0.000000
# 41           10014   103.879678
# 42           10014   103.879678
# 43           10014   103.879678
# 44           10014   103.879678
# 45           10014   103.879678
# 46           10014   103.879678
# 47           10014   103.879678
# 48           10014   103.879678
# 49           10004   274.529675

# %%
# merge end nearest zips column to main gdf
citibike_gdf = citibike_gdf.merge(
    end_zip_nearest_gdf[['ride_id', 'nearest_end_zip']],
    on='ride_id',
    how='left'
)

# fill in missing end_zip values with nearest zips
citibike_gdf['end_zip'] = citibike_gdf['end_zip'].fillna(citibike_gdf['nearest_end_zip'])

# drop nearest zip column
citibike_gdf = citibike_gdf.drop('nearest_end_zip', axis=1)

# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual  \
# 0  40.712297 -74.038185  40.737604 -74.052478        member
# 1  40.715391 -74.049692  40.719410 -74.043090        member
# 2  40.712419 -74.038526  40.716366 -74.034344        member
# 3  40.712419 -74.038526  40.716366 -74.034344        member
# 4  40.712419 -74.038526  40.719252 -74.034234        member
#
#            geometry_start            geometry_end start_zip end_zip
# 0  POINT (-74.038 40.712)  POINT (-74.052 40.738)     07302   07306
# 1   POINT (-74.05 40.715)  POINT (-74.043 40.719)     07302   07302
# 2  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302   07302
# 3  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302   07302
# 4  POINT (-74.039 40.712)  POINT (-74.034 40.719)     07302   07311

# %%
# double check if amount of nulls in end_zip = end_lat/lng
citibike_gdf.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3057
# end_station_id        3334
# start_lat                0
# start_lng                0
# end_lat                352
# end_lng                352
# member_casual            0
# geometry_start           0
# geometry_end             0
# start_zip                0
# end_zip                352
# dtype: int64

# %% [markdown]
# ### Get Cities, Counties, States

# %%
# join with cities gdf (start)
start_cities_joined_gdf = gpd.sjoin(citibike_gdf, cousubs_gdf, how='left', predicate='within')

# rename zip column
start_cities_joined_gdf = start_cities_joined_gdf.rename(columns={
    'NAME': 'start_city',
    'COUNTYFP': 'start_county',
    'STATEFP': 'start_state'
})

# merge start_zip back into citibike gdf
citibike_gdf[['start_city', 'start_county', 'start_state']] = start_cities_joined_gdf[['start_city', 'start_county', 'start_state']]

# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual  \
# 0  40.712297 -74.038185  40.737604 -74.052478        member
# 1  40.715391 -74.049692  40.719410 -74.043090        member
# 2  40.712419 -74.038526  40.716366 -74.034344        member
# 3  40.712419 -74.038526  40.716366 -74.034344        member
# 4  40.712419 -74.038526  40.719252 -74.034234        member
#
#            geometry_start            geometry_end start_zip end_zip  \
# 0  POINT (-74.038 40.712)  POINT (-74.052 40.738)     07302   07306
# 1   POINT (-74.05 40.715)  POINT (-74.043 40.719)     07302   07302
# 2  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302   07302
# 3  POINT (-74.039 40.712)  POINT (-74.034 40.716)     07302   07302
# 4  POINT (-74.039 40.712)  POINT (-74.034 40.719)     07302   07311
#
#     start_city start_county start_state
# 0  Jersey City          017          34
# 1  Jersey City          017          34
# 2  Jersey City          017          34
# 3  Jersey City          017          34
# 4  Jersey City          017          34

# %%
# set end geometry to active geometry
ends_gdf = gpd.GeoDataFrame(
    citibike_gdf.copy(),
    geometry='geometry_end',
    crs='EPSG:4326'
)

# create end cities column
ends_joined_gdf = gpd.sjoin(ends_gdf, cousubs_gdf, how='left', predicate='within').rename(columns={
    'NAME': 'end_city',
    'COUNTYFP': 'end_county',
    'STATEFP': 'end_state',
})

# assign end zip to main gdf
citibike_gdf[['end_city', 'end_county', 'end_state']] = ends_joined_gdf[['end_city', 'end_county', 'end_state']]

# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng  ...          geometry_start            geometry_end  \
# 0  40.712297 -74.038185  ...  POINT (-74.038 40.712)  POINT (-74.052 40.738)
# 1  40.715391 -74.049692  ...   POINT (-74.05 40.715)  POINT (-74.043 40.719)
# 2  40.712419 -74.038526  ...  POINT (-74.039 40.712)  POINT (-74.034 40.716)
# 3  40.712419 -74.038526  ...  POINT (-74.039 40.712)  POINT (-74.034 40.716)
# 4  40.712419 -74.038526  ...  POINT (-74.039 40.712)  POINT (-74.034 40.719)
#
#   start_zip end_zip   start_city start_county start_state     end_city  \
# 0     07302   07306  Jersey City          017          34  Jersey City
# 1     07302   07302  Jersey City          017          34  Jersey City
# 2     07302   07302  Jersey City          017          34  Jersey City
# 3     07302   07302  Jersey City          017          34  Jersey City
# 4     07302   07311  Jersey City          017          34  Jersey City
#
#   end_county end_state
# 0        017        34
# 1        017        34
# 2        017        34
# 3        017        34
# 4        017        34
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Double checking counties--> missing end counties are in NYC (have several counties within it)

# %%
# look into nulls
citibike_gdf.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3057
# end_station_id        3334
# start_lat                0
# start_lng                0
# end_lat                352
# end_lng                352
# member_casual            0
# geometry_start           0
# geometry_end             0
# start_zip                0
# end_zip                352
# start_city               0
# start_county             0
# start_state              0
# end_city               352
# end_county            3342
# end_state              352
# dtype: int64

# %%
# see what's causing county nulls
null_counties_with_cities = citibike_gdf[citibike_gdf['end_county'].isna() & citibike_gdf['end_city'].notna()]
print(null_counties_with_cities['end_state'].value_counts())
print(null_counties_with_cities['end_city'].value_counts())
# Out:
# end_state
# 36    2990
# Name: count, dtype: int64
# end_city
# New York    2990
# Name: count, dtype: int64

# %% [markdown]
# #### Add missing end counties from counties shapefile & update end_city

# %%
# fix gdf setup of end zip nulls with end coordinates
end_counties_nulls_gdf = null_counties_with_cities.iloc[:, :-3].reset_index(drop=True)

# set geometry to end coordinates and crs
end_counties_nulls_gdf = gpd.GeoDataFrame(
    end_counties_nulls_gdf,
    geometry='geometry_end',
    crs='EPSG:4326'
)

# create new end cities and counties column
end_counties_nulls_gdf = gpd.sjoin(end_counties_nulls_gdf, counties_gdf, how='left', predicate='within').rename(columns={
    'NAME': 'new_end_location',
    'COUNTYFP': 'new_end_county'
})

# display
end_counties_nulls_gdf[['ride_id', 'end_lat', 'end_lng', 'new_end_location', 'new_end_county']].head()
# Out:
#             ride_id    end_lat    end_lng new_end_location new_end_county
# 0  A040B477B036E5A8  40.707065 -74.007319         New York            061
# 1  479BDD97FE279988  40.717599 -74.015880         New York            061
# 2  70438D117D00C687  40.717571 -74.005549         New York            061
# 3  0D69EE4C57ECDE9E  40.750756 -73.978326         New York            061
# 4  19A542F7832439EC  40.750756 -73.978326         New York            061

# %%
# check if null counties
end_counties_nulls_gdf['new_end_county'].isna().sum()
# Out:
# 0

# %%
# check new recognized areas in nyc
end_counties_nulls_gdf['new_end_location'].value_counts()
# Out:
# new_end_location
# New York    2856
# Kings        110
# Queens        17
# Bronx          7
# Name: count, dtype: int64

# %%
# merge new end counties column to main gdf
citibike_gdf = citibike_gdf.merge(
    end_counties_nulls_gdf[['ride_id', 'new_end_county']],
    on='ride_id',
    how='left'
)

# fill in missing end_county values with new end county
citibike_gdf['end_county'] = citibike_gdf['end_county'].fillna(citibike_gdf['new_end_county'])

# drop new end county column
citibike_gdf = citibike_gdf.drop('new_end_county', axis=1)

# display
citibike_gdf.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0744109F13385D1D  electric_bike 2024-01-15 15:18:07 2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike 2024-01-13 15:32:50 2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00 2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49 2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10 2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng  ...          geometry_start            geometry_end  \
# 0  40.712297 -74.038185  ...  POINT (-74.038 40.712)  POINT (-74.052 40.738)
# 1  40.715391 -74.049692  ...   POINT (-74.05 40.715)  POINT (-74.043 40.719)
# 2  40.712419 -74.038526  ...  POINT (-74.039 40.712)  POINT (-74.034 40.716)
# 3  40.712419 -74.038526  ...  POINT (-74.039 40.712)  POINT (-74.034 40.716)
# 4  40.712419 -74.038526  ...  POINT (-74.039 40.712)  POINT (-74.034 40.719)
#
#   start_zip end_zip   start_city start_county start_state     end_city  \
# 0     07302   07306  Jersey City          017          34  Jersey City
# 1     07302   07302  Jersey City          017          34  Jersey City
# 2     07302   07302  Jersey City          017          34  Jersey City
# 3     07302   07302  Jersey City          017          34  Jersey City
# 4     07302   07311  Jersey City          017          34  Jersey City
#
#   end_county end_state
# 0        017        34
# 1        017        34
# 2        017        34
# 3        017        34
# 4        017        34
#
# [5 rows x 23 columns]

# %%
# double check null values
citibike_gdf.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3057
# end_station_id        3334
# start_lat                0
# start_lng                0
# end_lat                352
# end_lng                352
# member_casual            0
# geometry_start           0
# geometry_end             0
# start_zip                0
# end_zip                352
# start_city               0
# start_county             0
# start_state              0
# end_city               352
# end_county             352
# end_state              352
# dtype: int64

# %% [markdown]
# ## Find Station Names/IDs
# ---

# %% [markdown]
# ### Look at null stations

# %%
# check nulls
citibike_gdf.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3057
# end_station_id        3334
# start_lat                0
# start_lng                0
# end_lat                352
# end_lng                352
# member_casual            0
# geometry_start           0
# geometry_end             0
# start_zip                0
# end_zip                352
# start_city               0
# start_county             0
# start_state              0
# end_city               352
# end_county             352
# end_state              352
# dtype: int64

# %% [markdown]
# ### GeoDataFame for Stations

# %%
stations_gdf = gpd.GeoDataFrame(
    stations_df,
    geometry=gpd.points_from_xy(stations_df['lon'], stations_df['lat']),
    crs='EPSG:4326'
)

# display
stations_gdf.head()
# Out:
#   short_name                      name  region_id        lat        lon  \
# 0    7082.08            23 Ave & 31 St       71.0  40.774233 -73.912749
# 1    3460.06             2 Ave & 37 St       71.0  40.656240 -74.009330
# 2    8472.06  Valentine Ave & E 183 St       71.0  40.856987 -73.898237
# 3    5540.06             56 Dr & 61 St       71.0  40.723680 -73.904580
# 4    8717.07     E 201 St & Briggs Ave       71.0  40.872070 -73.884590
#
#                  geometry
# 0  POINT (-73.913 40.774)
# 1  POINT (-74.009 40.656)
# 2  POINT (-73.898 40.857)
# 3  POINT (-73.905 40.724)
# 4  POINT (-73.885 40.872)

# %% [markdown]
# ### Null Start Station --> lat/lng values are too rounded to pinpoint station

# %%
# look into nulls
start_station_nulls = citibike_gdf[citibike_gdf['start_station_name'].isna()].copy()
start_station_nulls.head()
# Out:
#                 ride_id  rideable_type          started_at  \
# 36634  D64972661F0BC489  electric_bike 2024-01-15 08:43:12
# 62036  4F05F77F14AF5FDD  electric_bike 2024-02-26 10:11:20
# 71216  FF2E6D36231516C0  electric_bike 2024-02-26 08:04:57
# 73088  8F9C5D5E5B6AFE7C  electric_bike 2024-02-25 16:45:08
# 74552  8C67DB90D434C1AF  electric_bike 2024-02-27 17:49:39
#
#                  ended_at start_station_name start_station_id  \
# 36634 2024-01-15 08:48:39                NaN              NaN
# 62036 2024-02-26 10:13:44                NaN              NaN
# 71216 2024-02-26 08:10:10                NaN              NaN
# 73088 2024-02-25 17:04:50                NaN              NaN
# 74552 2024-02-27 18:10:18                NaN              NaN
#
#                  end_station_name end_station_id  start_lat  start_lng  ...  \
# 36634                Newport PATH          JC066      40.71     -74.04  ...
# 62036  Stevens - River Ter & 6 St          HB602      40.74     -74.03  ...
# 71216            Marin Light Rail          JC013      40.72     -74.05  ...
# 73088                 Exchange Pl          JC116      40.74     -74.03  ...
# 74552       Baldwin at Montgomery          JC020      40.72     -74.06  ...
#
#              geometry_start            geometry_end start_zip end_zip  \
# 36634  POINT (-74.04 40.71)  POINT (-74.034 40.727)     07302   07310
# 62036  POINT (-74.03 40.74)  POINT (-74.027 40.743)     07030   07030
# 71216  POINT (-74.05 40.72)  POINT (-74.043 40.715)     07302   07302
# 73088  POINT (-74.03 40.74)  POINT (-74.034 40.716)     07030   07302
# 74552  POINT (-74.06 40.72)  POINT (-74.064 40.724)     07304   07304
#
#         start_city start_county start_state     end_city end_county end_state
# 36634  Jersey City          017          34  Jersey City        017        34
# 62036      Hoboken          017          34      Hoboken        017        34
# 71216  Jersey City          017          34  Jersey City        017        34
# 73088      Hoboken          017          34  Jersey City        017        34
# 74552  Jersey City          017          34  Jersey City        017        34
#
# [5 rows x 23 columns]

# %%
# see number of lat/lon values that have only 2 decimal places or less
broad_start_lats = [lat for lat in start_station_nulls['start_lat'] if str(lat)[::-1].find('.') <= 2]
broad_start_lons = [lon for lon in start_station_nulls['start_lng'] if str(lon)[::-1].find('.') <= 2]

print(len(broad_start_lats))
print(len(broad_start_lons))
# Out:
# 104
# 104

# %%
# see if rounded lat/lngs are unique in station
rounded_stations = stations_df.copy()
rounded_stations.lat = round(rounded_stations.lat, 2)
rounded_stations.lon = round(rounded_stations.lon, 2)

# groupby lat/lng and count
group_rounded = rounded_stations.groupby(['lat', 'lon']).size().reset_index(name='count')
dupe_cnts = group_rounded[group_rounded['count']>1]
dupe_cnts
# Out:
#        lat    lon  count
# 1    40.64 -74.03      3
# 2    40.64 -74.02      9
# 3    40.64 -74.01     10
# 6    40.64 -73.98      4
# 7    40.64 -73.97      6
# ..     ...    ...    ...
# 282  40.88 -73.91      6
# 283  40.88 -73.90      8
# 284  40.88 -73.89      9
# 285  40.88 -73.88      2
# 286  40.89 -73.90      3
#
# [262 rows x 3 columns]

# %%
# check if any are unique--> no
dupe_cnts[dupe_cnts['count']==1]
# Out:
# Empty DataFrame
# Columns: [lat, lon, count]
# Index: []

# %% [markdown]
# ### Null End Station ID but with Station Name

# %%
# look into null end station ids with names
null_end_station_ids = citibike_gdf[citibike_gdf['end_station_id'].isna() & citibike_gdf['end_station_name'].notna()].copy()
null_end_station_ids
# Out:
#                   ride_id  rideable_type              started_at  \
# 106702   9A9DFAC166C798C4  electric_bike 2024-03-29 19:03:15.000
# 107337   D0F18FBDC5E69B00  electric_bike 2024-03-28 21:43:02.000
# 107723   8ABA108361A7BD96  electric_bike 2024-03-29 13:29:59.000
# 107726   859FEA1C4E825877  electric_bike 2024-03-29 13:06:10.000
# 111112   A7456E42304BF4AE  electric_bike 2024-03-28 16:57:17.000
# ...                   ...            ...                     ...
# 1045635  6D2DAB1D9BD76A9C  electric_bike 2024-12-12 13:32:26.462
# 1045641  E0719548E8A96127  electric_bike 2024-12-12 14:11:50.661
# 1046286  464D005D5A83D756  electric_bike 2024-12-12 15:02:15.139
# 1046621  F3E3235AED147C12  electric_bike 2024-12-12 15:13:29.020
# 1048475  3163590F506F589E  electric_bike 2024-12-12 15:41:56.501
#
#                        ended_at                       start_station_name  \
# 106702  2024-03-29 19:06:56.000                           Pershing Field
# 107337  2024-03-28 21:45:50.000         City Hall - Washington St & 1 St
# 107723  2024-03-29 13:41:42.000                             Manila & 1st
# 107726  2024-03-29 13:22:48.000         City Hall - Washington St & 1 St
# 111112  2024-03-28 17:01:14.000  Hoboken Terminal - River St & Hudson Pl
# ...                         ...                                      ...
# 1045635 2024-12-12 13:35:22.806         City Hall - Washington St & 1 St
# 1045641 2024-12-12 14:14:26.323         City Hall - Washington St & 1 St
# 1046286 2024-12-12 15:10:41.903                        5 Corners Library
# 1046621 2024-12-12 15:15:03.341                             Manila & 1st
# 1048475 2024-12-12 15:59:21.035               Stevens - River Ter & 6 St
#
#         start_station_id       end_station_name end_station_id  start_lat  \
# 106702             JC024         Riverview Park            NaN  40.742406
# 107337             HB105      Madison St & 1 St            NaN  40.737225
# 107723             JC082         Riverview Park            NaN  40.721709
# 107726             HB105         Riverview Park            NaN  40.737251
# 111112             HB102      Madison St & 1 St            NaN  40.735961
# ...                  ...                    ...            ...        ...
# 1045635            HB105      Madison St & 1 St            NaN  40.737360
# 1045641            HB105      Madison St & 1 St            NaN  40.737360
# 1046286            JC018        Christ Hospital            NaN  40.734961
# 1046621            JC082           Jersey & 3rd            NaN  40.721651
# 1048475            HB602  11 St & Washington St            NaN  40.743133
#
#          start_lng  ...          geometry_start          geometry_end  \
# 106702  -74.052011  ...  POINT (-74.052 40.742)  POINT (-74.04 40.74)
# 107337  -74.031022  ...  POINT (-74.031 40.737)  POINT (-74.04 40.74)
# 107723  -74.042933  ...  POINT (-74.043 40.722)  POINT (-74.04 40.74)
# 107726  -74.030991  ...  POINT (-74.031 40.737)  POINT (-74.04 40.74)
# 111112  -74.029133  ...  POINT (-74.029 40.736)  POINT (-74.04 40.74)
# ...            ...  ...                     ...                   ...
# 1045635 -74.030970  ...  POINT (-74.031 40.737)  POINT (-74.04 40.74)
# 1045641 -74.030970  ...  POINT (-74.031 40.737)  POINT (-74.04 40.74)
# 1046286 -74.059503  ...   POINT (-74.06 40.735)  POINT (-74.05 40.73)
# 1046621 -74.042884  ...  POINT (-74.043 40.722)  POINT (-74.05 40.72)
# 1048475 -74.026989  ...  POINT (-74.027 40.743)  POINT (-74.03 40.75)
#
#         start_zip end_zip   start_city start_county start_state     end_city  \
# 106702      07307   07030  Jersey City          017          34      Hoboken
# 107337      07030   07030      Hoboken          017          34      Hoboken
# 107723      07302   07030  Jersey City          017          34      Hoboken
# 107726      07030   07030      Hoboken          017          34      Hoboken
# 111112      07030   07030      Hoboken          017          34      Hoboken
# ...           ...     ...          ...          ...         ...          ...
# 1045635     07030   07030      Hoboken          017          34      Hoboken
# 1045641     07030   07030      Hoboken          017          34      Hoboken
# 1046286     07306   07302  Jersey City          017          34  Jersey City
# 1046621     07302   07302  Jersey City          017          34  Jersey City
# 1048475     07030   07030      Hoboken          017          34      Hoboken
#
#         end_county end_state
# 106702         017        34
# 107337         017        34
# 107723         017        34
# 107726         017        34
# 111112         017        34
# ...            ...       ...
# 1045635        017        34
# 1045641        017        34
# 1046286        017        34
# 1046621        017        34
# 1048475        017        34
#
# [277 rows x 23 columns]

# %%
# lower name values before merging
null_end_station_ids['end_station_name'] = null_end_station_ids['end_station_name'].str.lower()
nlower_stations_df = stations_df.copy()
nlower_stations_df['name'] = nlower_stations_df['name'].str.lower()

# check if station names are unique in stations df--> YES
print(nlower_stations_df.nunique())


# merge on station name
not_null_end_station_ids = pd.merge(
    null_end_station_ids,
    nlower_stations_df,
    left_on='end_station_name',
    right_on='name',
    how='left'
)

# display
not_null_end_station_ids[['ride_id', 'end_station_name', 'name', 'end_station_id', 'short_name', 'end_lat', 'end_lng', 'lat', 'lon']]
# Out:
# short_name    2231
# name          2231
# region_id        3
# lat           2218
# lon           2214
# dtype: int64
#               ride_id       end_station_name                   name  \
# 0    9A9DFAC166C798C4         riverview park         riverview park
# 1    D0F18FBDC5E69B00      madison st & 1 st      madison st & 1 st
# 2    8ABA108361A7BD96         riverview park         riverview park
# 3    859FEA1C4E825877         riverview park         riverview park
# 4    A7456E42304BF4AE      madison st & 1 st      madison st & 1 st
# ..                ...                    ...                    ...
# 272  6D2DAB1D9BD76A9C      madison st & 1 st      madison st & 1 st
# 273  E0719548E8A96127      madison st & 1 st      madison st & 1 st
# 274  464D005D5A83D756        christ hospital        christ hospital
# 275  F3E3235AED147C12           jersey & 3rd           jersey & 3rd
# 276  3163590F506F589E  11 st & washington st  11 st & washington st
#
#     end_station_id short_name  end_lat  end_lng        lat        lon
# 0              NaN      JC057    40.74   -74.04  40.744319 -74.043991
# 1              NaN      HB402    40.74   -74.04  40.738790 -74.039300
# 2              NaN      JC057    40.74   -74.04  40.744319 -74.043991
# 3              NaN      JC057    40.74   -74.04  40.744319 -74.043991
# 4              NaN      HB402    40.74   -74.04  40.738790 -74.039300
# ..             ...        ...      ...      ...        ...        ...
# 272            NaN      HB402    40.74   -74.04  40.738790 -74.039300
# 273            NaN      HB402    40.74   -74.04  40.738790 -74.039300
# 274            NaN      JC034    40.73   -74.05  40.734786 -74.050444
# 275            NaN      JC074    40.72   -74.05  40.723332 -74.045953
# 276            NaN      HB502    40.75   -74.03  40.749985 -74.027150
#
# [277 rows x 9 columns]

# %%
# check amount if any null ids now
not_null_end_station_ids['short_name'].count()
# Out:
# 277

# %%
# merge end ids into main gdf
citibike_gdf = citibike_gdf.merge(
    not_null_end_station_ids[['ride_id', 'short_name']],
    on='ride_id',
    how='left'
)

# fill in missing end_station_ids
citibike_gdf['end_station_id'] = citibike_gdf['end_station_id'].fillna(citibike_gdf['short_name'])

# drop short name col
citibike_gdf = citibike_gdf.drop('short_name', axis=1)

# check nulls now (should be: end_station_name = end_station_id)
citibike_gdf.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     104
# start_station_id       104
# end_station_name      3057
# end_station_id        3057
# start_lat                0
# start_lng                0
# end_lat                352
# end_lng                352
# member_casual            0
# geometry_start           0
# geometry_end             0
# start_zip                0
# end_zip                352
# start_city               0
# start_county             0
# start_state              0
# end_city               352
# end_county             352
# end_state              352
# dtype: int64

# %% [markdown]
# ### Null End Station Name/ID

# %%
# look into nulls (end_station_name)
end_station_nulls = citibike_gdf[citibike_gdf['end_station_name'].isna() & citibike_gdf['end_lat'].notna()].copy()
end_station_nulls[['ride_id', 'end_station_id', 'end_station_name', 'end_lat', 'end_lng']]
# Out:
#                   ride_id end_station_id end_station_name  end_lat  end_lng
# 106      C18374AB46D402E2            NaN              NaN    40.73   -74.05
# 110      DF52F569EAD7B3C7            NaN              NaN    40.72   -74.05
# 111      5005A0EDC82C9470            NaN              NaN    40.71   -74.09
# 113      3D7F554CA1AF23EF            NaN              NaN    40.71   -74.06
# 114      9BECE19B5DBC34FE            NaN              NaN    40.72   -74.07
# ...                   ...            ...              ...      ...      ...
# 1025893  34FBB991D156EFBC            NaN              NaN    40.74   -74.03
# 1025899  663574E54A39EEF9            NaN              NaN    40.72   -74.04
# 1025909  FEB7C71275AB0E65            NaN              NaN    40.74   -74.03
# 1025910  36FADFF6DBDD32C9            NaN              NaN    40.70   -74.08
# 1025915  70C2D7799B7FBE6C            NaN              NaN    40.74   -74.03
#
# [2705 rows x 5 columns]

# %%
# see number of lat/lon values that have only 2 decimal places or less
broad_end_lats = [lat for lat in end_station_nulls['start_lat'] if str(lat)[::-1].find('.') <= 2]
broad_end_lons = [lon for lon in end_station_nulls['start_lng'] if str(lon)[::-1].find('.') <= 2]

print(len(broad_end_lats))
print(len(broad_end_lons))
# Out:
# 46
# 46

# %% [markdown]
# ### Get station ID's based on lat/lng

# %%
# save null start station names/ids
start_station_nulls = citibike_gdf[citibike_gdf['start_station_name'].isna()].copy()

# set up gdf
start_station_nulls_gdf = gpd.GeoDataFrame(
    start_station_nulls,
    geometry='geometry_start',
    crs='EPSG:4326'
)

# reproject points to local projected crs (feet)
starts_proj = start_station_nulls_gdf .to_crs('EPSG:2263')
stations_proj = stations_gdf.to_crs('EPSG:2263')

# spatial join to find nearest station
start_station_nulls_gdf = gpd.sjoin_nearest(
    starts_proj,
    stations_proj,
    how='left',
    distance_col='dist_to_station'
)

# rename columns
start_station_nulls_gdf = start_station_nulls_gdf.rename(columns={
    'short_name': 'new_start_station_id',
    'name': 'new_start_station_name'
})

# display
start_station_nulls_gdf[['new_start_station_id', 'new_start_station_name','lat', 'lon', 'start_lat', 'start_lng', 'dist_to_station']]
# Out:
#        new_start_station_id new_start_station_name        lat        lon  \
# 36634                 JC072           Morris Canal  40.712419 -74.038526
# 62036                 HB611        4 St & River St  40.740814 -74.027406
# 71216                 JC099          Montgomery St  40.719420 -74.050990
# 73088                 HB611        4 St & River St  40.740814 -74.027406
# 74552                 JC020  Baldwin at Montgomery  40.723659 -74.064194
# ...                     ...                    ...        ...        ...
# 250908                JC014         Columbus Drive  40.718355 -74.038914
# 327020                JC072           Morris Canal  40.712419 -74.038526
# 432538                JC002            Paulus Hook  40.714145 -74.033552
# 799902                JC094           Glenwood Ave  40.727551 -74.071061
# 800427                JC020  Baldwin at Montgomery  40.723659 -74.064194
#
#         start_lat  start_lng  dist_to_station
# 36634       40.71     -74.04       971.444107
# 62036       40.74     -74.03       777.540570
# 71216       40.72     -74.05       346.356912
# 73088       40.74     -74.03       777.540570
# 74552       40.72     -74.06      1768.814755
# ...           ...        ...              ...
# 250908      40.72     -74.04       670.563128
# 327020      40.71     -74.04       971.444107
# 432538      40.71     -74.03      1802.947865
# 799902      40.73     -74.07       939.272537
# 800427      40.72     -74.06      1768.814755
#
# [104 rows x 7 columns]
